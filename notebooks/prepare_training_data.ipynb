# %% [markdown]
# # Prepare training data for Phi2 fine-tuning

# %% [markdown]
# In this notebook, we will be preparing high-quality MCQs for fine-tuning Phi2 small LLM model.
# The training set will consist of MCQs with an evaluation score between 0.7 and 0.85. The test set will consist of MCQs with an evaluation score above 0.85.

# %% [markdown]
# ## Imports

# %%
import sys
from pathlib import Path

# Add the root directory to sys.path
root_path = Path().resolve().parent
sys.path.append(str(root_path))

# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.training_formatter import TrainingFormatter

# %% [markdown]
# ## Prepare training data

# %%
EVAL_CSV = "../data/evaluation_scores/mcq_eval_scores_1000.csv"
OUT_JSONL_1 = "../data/training_jsonl/mcqs_all_1000.jsonl"
OUT_JSONL_2 = "../data/training_jsonl/mcqs_filtered_07_1000.jsonl"
OUT_JSONL_3 = "../data/training_jsonl/mcqs_filtered_085_1000.jsonl"

# %%
df = pd.read_csv(EVAL_CSV)
df
# Out:
#                              focus  \
# 0                       Diphtheria
# 1              trichothiodystrophy
# 2                Nemaline myopathy
# 3           Gracile bone dysplasia
# 4         Gastrocutaneous syndrome
# ..                             ...
# 995                       Cataract
# 996                   Pericarditis
# 997              Ectopic Pregnancy
# 998            15q24 microdeletion
# 999  Melanoma astrocytoma syndrome
#
#                                                 qtypes  \
# 0                                      ['information']
# 1    ['frequency', 'genetic changes', 'information'...
# 2                                      ['information']
# 3                                         ['symptoms']
# 4                                         ['symptoms']
# ..                                                 ...
# 995  ['susceptibility', 'symptoms', 'treatment', 'i...
# 996  ['information', 'causes', 'susceptibility', 's...
# 997                                    ['information']
# 998  ['frequency', 'genetic changes', 'information'...
# 999                                       ['symptoms']
#
#                                                summary  \
# 0    Diphtheria is a serious bacterial infection ca...
# 1    Trichothiodystrophy is a rare, inherited condi...
# 2    Nemaline myopathy is a genetic disorder that p...
# 3    Gracile bone dysplasia is a rare genetic disor...
# 4    Gastrocutaneous syndrome is a complex conditio...
# ..                                                 ...
# 995  A cataract is a clouding of the lens in the ey...
# 996  Pericarditis is a condition characterized by i...
# 997  An ectopic pregnancy occurs when a fertilized ...
# 998  15q24 microdeletion is a rare chromosomal diso...
# 999  Melanoma astrocytoma syndrome is a rare geneti...
#
#                                              objective  \
# 0    Describe the importance of timely vaccination ...
# 1    Analyze the inheritance pattern of a rare gene...
# 2    Identify the primary inheritance pattern of Ne...
# 3    Identify the primary cause of respiratory comp...
# 4    Identify a characteristic symptom associated w...
# ..                                                 ...
# 995  Analyze the relationship between environmental...
# 996  Evaluate the appropriate initial treatment app...
# 997  Identify the typical location where an ectopic...
# 998  Evaluate the relationship between a genetic co...
# 999  Identify the primary association between a spe...
#
#                                               question  \
# 0    A patient presents with symptoms of diphtheria...
# 1    A patient is diagnosed with Trichothiodystroph...
# 2    What is the typical genetic inheritance patter...
# 3    What is the primary reason why individuals wit...
# 4    Which of the following skin lesions is commonl...
# ..                                                 ...
# 995  A patient with a history of prolonged exposure...
# 996  A 35-year-old man presents with sudden onset o...
# 997  Where does an ectopic pregnancy most commonly ...
# 998  A patient diagnosed with 15q24 microdeletion p...
# 999  An individual with Melanoma astrocytoma syndro...
#
#                                                options answer  \
# 0    {'A': "The patient's immunity is likely to pro...      D
# 1    {'A': 'Autosomal dominant pattern, where one m...      C
# 2    {'A': 'Autosomal Dominant', 'B': 'X-linked Rec...      D
# 3    {'A': 'Cardiac anomalies leading to pulmonary ...      C
# 4    {'A': 'Pityriasis alba-like macules', 'B': 'Me...      B
# ..                                                 ...    ...
# 995  {'A': 'Macular degeneration', 'B': 'Cataract',...      B
# 996  {'A': 'Order an emergency echocardiogram to ev...      B
# 997  {'A': 'Ovaries', 'B': 'Fallopian tubes', 'C': ...      B
# 998  {'A': 'The deletion of 1-6 million DNA base pa...      B
# 999  {'A': 'Colorectal carcinoma', 'B': 'Cutaneous ...      B
#
#                                            explanation  relevance_to_summary  \
# 0    Given the patient's vaccination history and th...              0.708517
# 1    Trichothiodystrophy is inherited in an autosom...              0.792817
# 2    Nemaline Myopathy is primarily inherited in an...              0.801020
# 3    Individuals with Gracile bone dysplasia are at...              0.683419
# 4    Melanocytic nevi are a characteristic skin les...              0.678607
# ..                                                 ...                   ...
# 995  Prolonged exposure to ultraviolet sunlight has...              0.474832
# 996  Colchicine and prednisone are anti-inflammator...              0.579525
# 997  The correct answer is B, as fallopian tubes ar...              0.626850
# 998  Individuals with 15q24 microdeletion are at ri...              0.737288
# 999  Melanoma astrocytoma syndrome is characterized...              0.763935
#
#      alignement_with_objective  plausibility_of_distractors  plausibility_qa  \
# 0                     0.736968                        0.833              1.0
# 1                     0.544787                        0.750              1.0
# 2                     0.921066                        0.833              1.0
# 3                     0.878695                        0.917              1.0
# 4                     0.729024                        1.000              1.0
# ..                         ...                          ...              ...
# 995                   0.507629                        1.000              1.0
# 996                   0.427334                        0.833              1.0
# 997                   0.858277                        1.000              1.0
# 998                   0.625763                        1.000              1.0
# 999                   0.633216                        0.833              1.0
#
#      medical_validity  average
# 0                 1.0    0.856
# 1                 1.0    0.818
# 2                 1.0    0.911
# 3                 1.0    0.896
# 4                 1.0    0.882
# ..                ...      ...
# 995               0.5    0.696
# 996               1.0    0.768
# 997               0.5    0.797
# 998               1.0    0.873
# 999               1.0    0.846
#
# [1000 rows x 14 columns]

# %%
formatter = TrainingFormatter()

# %%
data_all = formatter.format_dataframe(df)
formatter.save_jsonl(data_all, OUT_JSONL_1)
# Out:
# Saved 1000 formatted mcq in ../data/training_jsonl/mcqs_all_1000.jsonl

# %%
df_07 = df[(df["average"] >= 0.7) & (df["average"] < 0.85)]
data_07 = formatter.format_dataframe(df_07)
formatter.save_jsonl(data_07, OUT_JSONL_2)
# Out:
# Saved 635 formatted mcq in ../data/training_jsonl/mcqs_filtered_07_1000.jsonl
# (635, 14)

# %%
df_085 = df[df["average"] >= 0.85]
data_085 = formatter.format_dataframe(df_085)
formatter.save_jsonl(data_085, OUT_JSONL_3)
# Out:
# Saved 294 formatted mcq in ../data/training_jsonl/mcqs_filtered_085_1000.jsonl
# (294, 14)
